# %%
import requests
import pandas as pd

# %% [markdown]
# # Contracts

# %%
requests.get('https://api.bscscan.com/api?module=contract&action=getabi&address=0x0e09fabb73bd3ade0a17ecc321fd13a19e81ce82&apikey=MRZWYSV9QP6QTG4K5KFS3MX4QZ4T7T4H7D').json()
# Out:
# {'status': '1',
#  'message': 'OK',
# ...

# %% [markdown]
# # Transactions

# %%
requests.get('https://api.bscscan.com/api?module=transaction&action=gettxreceiptstatus&txhash=0xe9975702518c79caf81d5da65dea689dcac701fcdd063f848d4f03c85392fd00&apikey=MRZWYSV9QP6QTG4K5KFS3MX4QZ4T7T4H7D').json()
# Out:
# {'status': '1', 'message': 'OK', 'result': {'status': '1'}}

# %% [markdown]
# # Block Rewards

# %%
requests.get('https://api.bscscan.com/api?module=block&action=getblockreward&blockno=2170000&apikey=MRZWYSV9QP6QTG4K5KFS3MX4QZ4T7T4H7D').json()
# Out:
# {'status': '1',
#  'message': 'OK',
#  'result': {'blockNumber': '2170000',
#   'timeStamp': '1605182836',
#   'blockMiner': '0x68bf0b8b6fb4e317a0f9d6f03eaf8ce6675bc60d',
#   'blockReward': '13657915000000000',
#   'uncles': [],
#   'uncleInclusionReward': '0'}}

# %% [markdown]
# # Log API query example

# %%
logs = pd.DataFrame(requests.get('https://api.bscscan.com/api?module=logs&action=getLogs&fromBlock=4993830&toBlock=4993832&address=0xe561479bebee0e606c19bb1973fc4761613e3c42&topic0=0xddf252ad1be2c89b69c2b068fc378daa952ba7f163c4a11628f55a4df523b3ef&apikey=MRZWYSV9QP6QTG4K5KFS3MX4QZ4T7T4H7D').json()['result'])
logs.T
# Out:
#                                                                  0   \
# address                  0xe561479bebee0e606c19bb1973fc4761613e3c42
# topics            [0xddf252ad1be2c89b69c2b068fc378daa952ba7f163c...
# data              0x00000000000000000000000000000000000000000000...
# blockNumber                                                0x4c3326
# timeStamp                                                0x602e9ef1
# gasPrice                                                0x2540be400
# gasUsed                                                     0x1b0f2
# logIndex                                                       0xf7
# transactionHash   0x73844fcfc6beab2e973a897c9573f4d79811b12213ce...
# transactionIndex                                               0xb9
#
#                                                                  1   \
# address                  0xe561479bebee0e606c19bb1973fc4761613e3c42
# topics            [0xddf252ad1be2c89b69c2b068fc378daa952ba7f163c...
# ...

# %% [markdown]
# # Get Block Transaction Count by Number

# %%
requests.get('https://api.bscscan.com/api?module=proxy&action=eth_getBlockTransactionCountByNumber&tag=0xa11446&apikey=MRZWYSV9QP6QTG4K5KFS3MX4QZ4T7T4H7D').json()
# Out:
# {'jsonrpc': '2.0', 'id': 1, 'result': '0xfc'}

# %% [markdown]
# # Tokens

# %%
requests.get('https://api.bscscan.com/api?module=stats&action=tokenCsupply&contractaddress=0xe9e7cea3dedca5984780bafc599bd69add087d56&apikey=MRZWYSV9QP6QTG4K5KFS3MX4QZ4T7T4H7D').json()
# Out:
# {'status': '1', 'message': 'OK', 'result': '4731687544856933531005304958'}

# %% [markdown]
# # Gas Tracker

# %%
requests.get('https://api.bscscan.com/api?module=gastracker&action=gasoracle&apikey=MRZWYSV9QP6QTG4K5KFS3MX4QZ4T7T4H7D').json()
# Out:
# {'status': '1',
#  'message': 'OK',
#  'result': {'LastBlock': '12537951',
#   'SafeGasPrice': '5',
#   'ProposeGasPrice': '5',
#   'FastGasPrice': '7',
#   'UsdPrice': '644.65'}}

# %% [markdown]
# # Stats

# %%
requests.get('https://api.bscscan.com/api?module=stats&action=bnbsupply&apikey=MRZWYSV9QP6QTG4K5KFS3MX4QZ4T7T4H7D').json()
# Out:
# {'status': '1', 'message': 'OK', 'result': '22389302531143300000000000'}
